# %% [markdown]
# Es 1
#
# Write a program that asks the user for the base and height of
# a rectangle. Then print the perimeter and area value
# of the rectangle.

# %%
# compute_perimeter (b, h) function that receives two parameters (base, height) in input and compute the perimeter
def compute_perimter(b,h):
  return (b+h)*2


# computer_area (b, h) function that receives two parameters (base, height) in input and computer the area
def computer_area(b,h):
  return b*h


# write the instructions to receive in input base and height and call the functions

b = input("Inserisci la base ")
h = input("Inserisci l'altezza ")

print("Il perimetro è ")
P = compute_perimter(int(b),int(h))
print(P)
print("L'area è ")
A = computer_area(int(b),int(h))
print(A)
# Out:
# Il perimetro è
# 180
# L'area è
# 2025

# %% [markdown]
# Es 2
#
# s = input("What is your name? ")
#
# Print the type of the variable s, the length, the first and last character.

# %%
s = input("What is your name? ")

#Print the type of the variable s,
print(type(s))

#the length,
print(len(s))

#the first and last character.
print(s[0],s[len(s)-1])
# Out:
# <class 'str'>
# 1
# 2 2

# %% [markdown]
# Es 3
#
# Write a program that asks for two numbers. If the sum of the two
# number exceeds 100, print ``Number too large''

# %%
# ask number x

x = input("Inserisci un numero")

# ask number y

y = input("Inserisci un altro numero")

# compute the sum

x = int(x)
y = int(y)

def sum(x,y):
    return x + y

S = sum(x, y)

# verify the condition and add print

if S > 100:
    print("Number too large")

# %% [markdown]
# Es 4
# *   Fill an initially empty list with 10 values ​​read from keyboard.
# *   Print the largest and smallest value contained in the list

# %%
n = 6

# Empty list

L = list(range(n))

# Iterate

for i in range(n):

# Ask for value
    tmp = input("Inserisci un numero")

# Fill
    L[i] = int(tmp)

# Temp max
max = L[0]
# Temp min
min = L[0]

# Iterate and check which is the max and the min
for i in range(n):
    if L[i] > max:
        max = L[i]
    if L[i] < min:
        min = L[i]

print("Il massimo è " + str(max) + " Il minimo è " + str(min))
# Out:
# Il massimo è 8 Il minimo è 4

# %% [markdown]
# Es 5
#
# After importing the numpy module create an array
# of 100 random numbers with integer values ​​between 0 and
# 50.
#
# Print all numbers greater than the mean and the
# their location
#
# NB: You find hints in the documentation

# %%
# import the numpy

import numpy as np

# create an array of 100 random numbers between 0 and 50

Arr = np.random.random_integers(0,50,100)

# compute the mean

avg = np.mean(Arr)

print("La media è " + str(avg))

# Print the expected number and the locations

for i in range(Arr.size):
    if Arr[i] > avg:
        print("Elemento: " + str(Arr[i]) + " in posizione " + str(i))
# Out:
# La media è 25.21
# Elemento: 50 in posizione 2
# Elemento: 49 in posizione 4
# Elemento: 27 in posizione 7
# Elemento: 43 in posizione 13
# Elemento: 46 in posizione 14
# Elemento: 36 in posizione 17
# Elemento: 27 in posizione 18
# Elemento: 43 in posizione 19
# Elemento: 35 in posizione 20
# Elemento: 30 in posizione 23
# Elemento: 48 in posizione 24
# Elemento: 50 in posizione 26
# Elemento: 28 in posizione 30
# Elemento: 34 in posizione 31
# Elemento: 46 in posizione 32
# Elemento: 31 in posizione 33
# Elemento: 44 in posizione 34
# Elemento: 45 in posizione 36
# Elemento: 31 in posizione 40
# Elemento: 49 in posizione 41
# Elemento: 43 in posizione 43
# Elemento: 43 in posizione 44
# Elemento: 47 in posizione 46
# Elemento: 40 in posizione 48
# Elemento: 31 in posizione 49
# Elemento: 40 in posizione 50
# Elemento: 46 in posizione 51
# Elemento: 40 in posizione 52
# Elemento: 29 in posizione 56
# Elemento: 49 in posizione 57
# Elemento: 47 in posizione 59
# Elemento: 45 in posizione 60
# Elemento: 46 in posizione 61
# Elemento: 27 in posizione 64
# Elemento: 45 in posizione 65
# Elemento: 36 in posizione 66
# Elemento: 31 in posizione 72
# Elemento: 32 in posizione 73
# Elemento: 32 in posizione 78
# Elemento: 40 in posizione 79
# Elemento: 39 in posizione 83
# Elemento: 47 in posizione 85
# Elemento: 37 in posizione 87
# Elemento: 37 in posizione 90
# Elemento: 41 in posizione 91
# Elemento: 37 in posizione 93
# Elemento: 45 in posizione 97
# Elemento: 41 in posizione 98
# Elemento: 30 in posizione 99
# C:\Users\giova\AppData\Local\Temp\ipykernel_3704\905119993.py:7: DeprecationWarning: This function is deprecated. Please call randint(0, 50 + 1) instead
#   Arr = np.random.random_integers(0,50,100)

# %% [markdown]
# Es 6
#
# Write a multiplier function(number_list) that
# given a list of numbers, multiply all of them together and returns the result. If the
# list is empty returns 0.

# %%
# define the function

def multiplier(number_list):
    # check if it is empty
    if len(number_list) <= 0:
        return 0
    tmp = 1
    # multiple the values
    for i in number_list:
        tmp *= i
    
    return tmp

# define the list and call the function

print(multiplier([1, 5, 7, 9, 3]))
print(multiplier([]))
print(multiplier([1, 5, 7, 0, 3]))
# Out:
# 945
# 0
# 0

# %% [markdown]
# Es 7
#
# Write a countdown(string) function.
# The function takes a string as a parameter and returns the
# string after making it lowercase all the
# characters and in uppercase only the last character (e.g
# example "abcd" becomes "dcbA"). Also manage the
# empty string case.

# %%
def countdown(str):
    if str == "":
        return str
    str = str.lower()
    last = str[len(str) - 1]
    last = last.upper()
    str = str[0:len(str) - 1] + last
    return str

print(countdown("CfdFFDGsfiaOHHS"))
print(countdown(""))
# Out:
# cfdffdgsfiaohhS

# %% [markdown]
# Es 8
#
# Write a function frequency(string). The function
# takes a string as a parameter and returns a
# dictionary representing the frequency of each
# character component of the string.
# For example, given a string "ababcc", the
# function returns result {"a": 2, "b": 2, "c":
# 2}.

# %%
def frequency(str):
    leng = len(str)
    res = dict()
    for i in range(leng):
        if str[i] in res:
            num = res[str[i]]
            res[str[i]] = num + 1    
        else:
            res[str[i]] = 1
    return res


dic = frequency("ababdfsacc")
print(dic)
# Out:
# {'a': 3, 'b': 2, 'd': 1, 'f': 1, 's': 1, 'c': 2}
